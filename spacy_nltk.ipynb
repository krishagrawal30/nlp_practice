# %%
pip install nltk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.7/803.7 kB 8.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [nltk]4/5 [nltk]]]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 -m spacy download en
# Out:
# /usr/bin/python3: No module named spacy

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
print("Model loaded successfully ✅")
# Out:
# Model loaded successfully ✅

# %% [markdown]
# ### Tokenization

# %%
doc = nlp("Dr. Krish is also a scientist, researcher, Engineer, etc. apart from student. He loves to play basketball and chess.")
for i in doc.sents:
    print(i)
# Out:
# Dr. Krish is also a scientist, researcher, Engineer, etc. apart from student.
# He loves to play basketball and chess.

# %%
for i in doc.sents:
    for w in i:
        print(w)
# Out:
# Dr.
# Krish
# is
# also
# a
# scientist
# ,
# researcher
# ,
# Engineer
# ,
# etc
# .
# apart
# from
# student
# .
# He
# loves
# to
# play
# basketball
# and
# chess
# .

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/krish_agrawal/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
sent_tokenize("Dr. Krish is also a scientist, researcher, Engineer, etc. apart from student. He loves to play basketball and chess.")
# Out:
# ['Dr. Krish is also a scientist, researcher, Engineer, etc.',
#  'apart from student.',
#  'He loves to play basketball and chess.']

# %%
word_tokenize("Dr. Krish is also a scientist, researcher, Engineer, etc. apart from student. He loves to play basketball and chess.")
# Out:
# ['Dr.',
#  'Krish',
#  'is',
#  'also',
#  'a',
#  'scientist',
#  ',',
#  'researcher',
#  ',',
#  'Engineer',
#  ',',
#  'etc',
#  '.',
#  'apart',
#  'from',
#  'student',
#  '.',
#  'He',
#  'loves',
#  'to',
#  'play',
#  'basketball',
#  'and',
#  'chess',
#  '.']

# %%
nlp1 = spacy.blank("en")

# %%
doc = nlp1("Dr. Krish is also a scientist, researcher, Engineer, etc. apart from student. He loves to play basketball and chess.")
for i in doc:
    print(i)
# Out:
# Dr.
# Krish
# is
# also
# a
# scientist
# ,
# researcher
# ,
# Engineer
# ,
# etc
# .
# apart
# from
# student
# .
# He
# loves
# to
# play
# basketball
# and
# chess
# .
