# %%
import re

# %%
a = 'Sure, my mobile number is +91 98765 43210 and my email is rahul.verma@gmail.com.'

b = 'You can reach me at (022) 2987-6543 and my email is ankit_123@yahoo.co.in'

c = 'My contact number is +91-91234-56789. Email: neha.singh@outlook.in.'

d = 'Phone: 091-99887-76655Mail ID: priya.sharma@company.org'

e  ='Here are my details: (+91) 9876543210, and email is rohit.kumar99@protonmail.com'

# %%
pat = r'\d{10}'
res = re.findall(pat, e)
print(res)
# Out:
# ['9876543210']

# %%
pat = r'\d{10}|\(\d{3}\) \d{4}-\d{4}'
res = re.findall(pat, b)
print(res)
# Out:
# ['(022) 2987-6543']

# %%
pat = r'([a-z0-9A-Z._]*)@[a-z]*\.[a-z]*'
res = re.findall(pat, a)
print(res)
# Out:
# ['rahul.verma']
