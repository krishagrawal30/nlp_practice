# %% [markdown]
# <h2 align='center'>NLP Tutorial: Text Representation - Bag Of Words (BOW)</h2>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\gitrepo\nlp_practice\bag of words\spam.csv")
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x =='spam' else 0)

# %%
df.shape
# Out:
# (5572, 3)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %% [markdown]
# <h3>Train test split</h3>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.Series

# %%
X_train[:4]
# Out:
# 4103    Ok then i will come to ur home after half an hour
# 2965    Do you ever notice that when you're driving, a...
# 877          Are you in castor? You need to see something
# 4209    Or i go home first lar ü wait 4 me lor.. I put...
# Name: Message, dtype: str

# %%
type(y_train)
# Out:
# pandas.Series

# %%
y_train[:4]
# Out:
# 4103    0
# 2965    1
# 877     0
# 4209    0
# Name: spam, dtype: int64

# %%
type(X_train.values)
# Out:
# pandas.arrays.StringArray

# %% [markdown]
# <h3>Create bag of words representation using CountVectorizer</h3>

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 59537 stored elements and shape (4457, 7780)>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(7780,))

# %%
X_train_cv.shape
# Out:
# (4457, 7780)

# %%
v.get_feature_names_out()[1771]
# Out:
# 'chgs'

# %%
v.vocabulary_
# Out:
# {'ok': 4929,
#  'then': 6861,
#  'will': 7559,
#  'come': 1902,
#  'to': 6968,
#  'ur': 7239,
#  'home': 3485,
#  'after': 841,
#  'half': 3318,
#  'an': 943,
#  'hour': 3523,
#  'do': 2382,
#  'you': 7744,
#  'ever': 2682,
#  'notice': 4850,
#  'that': 6844,
#  'when': 7520,
#  're': 5615,
#  'driving': 2467,
#  'anyone': 981,
#  'going': 3187,
#  'slower': 6267,
#  'than': 6832,
#  'is': 3759,
#  'idiot': 3607,
#  'and': 948,
#  'everyone': 2688,
#  'faster': 2799,
#  'maniac': 4358,
#  'are': 1036,
#  'in': 3653,
#  'castor': 1677,
#  'need': 4742,
#  'see': 6016,
#  'something': 6331,
#  'or': 4991,
#  'go': 3174,
#  'first': 2890,
#  'lar': 4028,
#  'wait': 7394,
#  'me': 4415,
#  'lor': 4218,
#  'put': 5534,
#  'down': 2437,
#  'my': 4680,
#  'stuff': 6569,
#  'yup': 7768,
#  'leaving': 4074,
#  'right': 5813,
#  'now': 4857,
#  'be': 1261,
#  'back': 1190,
#  'soon': 6347,
#  'fyi': 3071,
#  'at': 1106,
#  'usf': 7262,
#  'swing': 6688,
#  'by': 1587,
#  'the': 6847,
#  'room': 5852,
#  'whenever': 7521,
#  'what': 7513,
#  'mean': 4418,
#  'was': 7430,
#  'left': 4078,
#  'too': 7010,
#  'early': 2518,
#  'check': 1747,
#  'cos': 2017,
#  'working': 7634,
#  'met': 4473,
#  'alex': 892,
#  'nichols': 4786,
#  'from': 3038,
#  'middle': 4481,
#  'school': 5973,
#  'it': 3770,
#  'turns': 7115,
#  'out': 5025,
#  'he': 3384,
#  'dealing': 2197,
#  'whats': 7515,
#  'todays': 6975,
#  'plan': 5251,
#  'can': 1626,
#  'not': 4844,
#  'tap': 6737,
#  'spile': 6412,
#  'seven': 6071,
#  'pub': 5509,
#  'on': 4947,
#  'gas': 3096,
#  'st': 6457,
#  'off': 4905,
#  'broad': 1514,
#  'canal': 1628,
#  'im': 3627,
#  'good': 3198,
#  'have': 3373,
#  'been': 1285,
#  'thinking': 6881,
#  'about': 749,
#  'oh': 4924,
#  'fine': 2875,
#  'll': 4172,
#  'tonight': 7005,
#  'aiyah': 876,
#  'wat': 7436,
#  'as': 1074,
#  'long': 4203,
#  'got': 3214,
#  'improve': 3650,
#  'already': 912,
#  'dear': 2199,
#  'voucher': 7366,
#  'holder': 3477,
#  'claim': 1816,
#  'this': 6886,
#  'weeks': 7483,
#  'offer': 4910,
#  'pc': 5146,
#  'please': 5267,
#  'http': 3546,
#  'www': 7680,
#  'tlp': 6958,
#  'co': 1862,
#  'uk': 7154,
#  'expressoffer': 2744,
#  'ts': 7093,
#  'cs': 2096,
#  'apply': 1011,
#  'stop': 6523,
#  'texts': 6829,
#  'txt': 7129,
#  '80062': 633,
#  'funeral': 3061,
#  'with': 7586,
#  'audrey': 1131,
#  'dad': 2150,
#  'tiwary': 6951,
#  'rcb': 5609,
#  'battle': 1241,
#  'between': 1329,
#  'bang': 1210,
#  'kochi': 3982,
#  'doing': 2406,
#  'busy': 1571,
#  'wif': 7549,
#  'work': 7630,
#  'nothing': 4849,
#  'but': 1572,
#  'we': 7455,
#  'jus': 3889,
#  'tot': 7028,
#  'would': 7651,
#  'ask': 1084,
#  'ba': 1178,
#  'gua': 3276,
#  'went': 7498,
#  'mt': 4640,
#  'faber': 2757,
#  'yest': 7731,
#  'mah': 4325,
#  'so': 6311,
#  'today': 6974,
#  'call': 1603,
#  'gram': 3233,
#  'usually': 7268,
#  'runs': 5891,
#  'like': 4120,
#  'lt': 4262,
#  'gt': 3275,
#  'eighth': 2565,
#  'smarter': 6276,
#  'though': 6897,
#  'gets': 3134,
#  'almost': 909,
#  'whole': 7537,
#  'second': 6006,
#  'for': 2957,
#  'guessin': 3287,
#  'ain': 869,
#  'gonna': 3196,
#  'here': 3429,
#  'before': 1291,
#  'darren': 2173,
#  'saying': 5961,
#  'dat': 2177,
#  'if': 3612,
#  'meeting': 4435,
#  'da': 2146,
#  'ge': 3113,
#  'den': 2249,
#  'dun': 2498,
#  'meet': 4433,
#  'dinner': 2337,
#  'later': 4039,
#  'leave': 4072,
#  'xy': 7703,
#  'feel': 2822,
#  'awkward': 1166,
#  'him': 3446,
#  'lunch': 4273,
#  'dont': 2417,
#  'understand': 7180,
#  'your': 7749,
#  'message': 4466,
#  'where': 7523,
#  'tmr': 6962,
#  'our': 5024,
#  'customer': 2131,
#  'service': 6061,
#  'representative': 5751,
#  '0800': 49,
#  '169': 317,
#  '6031': 569,
#  '10am': 262,
#  '9pm': 729,
#  'won': 7615,
#  'guaranteed': 3279,
#  '1000': 257,
#  'cash': 1670,
#  '5000': 538,
#  'prize': 5442,
#  'liked': 4121,
#  'new': 4774,
#  'mobile': 4557,
#  'hey': 3436,
#  'happy': 3350,
#  'birthday': 1360,
#  'no': 4810,
#  'its': 3776,
#  'specialisation': 6393,
#  'slave': 6248,
#  'labor': 4003,
#  'look': 4207,
#  'month': 4592,
#  'sha': 6083,
#  'shakara': 6090,
#  'beggar': 1294,
#  'yes': 7730,
#  'small': 6272,
#  'kid': 3946,
#  'boost': 1430,
#  'secret': 6009,
#  'of': 4904,
#  'energy': 2609,
#  'always': 920,
#  'yahoo': 7706,
#  'messenger': 4471,
#  'just': 3890,
#  'send': 6041,
#  'get': 3131,
#  'may': 4408,
#  'mode': 4568,
#  'reply': 5746,
#  'borrow': 1438,
#  'bag': 1195,
#  '2morro': 401,
#  'term': 6801,
#  'over': 5043,
#  '2nite': 408,
#  'some': 6322,
#  'sexy': 6077,
#  'passion': 5120,
#  'b4': 1174,
#  'chat': 1739,
#  '09099726481': 250,
#  'luv': 4277,
#  'dena': 2250,
#  'calls': 1618,
#  'minmobsmorelkpobox177hp51fl': 4504,
#  'wot': 7647,
#  'up': 7220,
#  'thout': 6901,
#  'were': 7501,
#  'bak': 1200,
#  'she': 6106,
#  'told': 6985,
#  'hr': 3541,
#  'want': 7416,
#  'posting': 5348,
#  'chennai': 1761,
#  'because': 1272,
#  'asking': 1088,
#  'knw': 3980,
#  'them': 6857,
#  'nt': 4863,
#  'frnds': 3032,
#  'classmates': 1826,
#  'hasn': 3362,
#  'pattern': 5130,
#  'recently': 5656,
#  'crap': 2059,
#  'weekends': 7481,
#  'remember': 5715,
#  'day': 2186,
#  'huh': 3554,
#  'having': 3379,
#  'outside': 5036,
#  'izzit': 3785,
#  'had': 3307,
#  '10': 255,
#  'mths': 4643,
#  'update': 7225,
#  'latest': 4040,
#  'orange': 4995,
#  'camera': 1624,
#  'video': 7325,
#  'phones': 5210,
#  'free': 3003,
#  'save': 5953,
#  'weekend': 7480,
#  'text': 6819,
#  'callback': 1606,
#  'orno': 5009,
#  'opt': 4985,
#  'am': 922,
#  'way': 7451,
#  'could': 2029,
#  'seen': 6023,
#  'did': 2311,
#  'recognise': 5663,
#  'face': 2758,
#  'pls': 5275,
#  'make': 4338,
#  'note': 4845,
#  'all': 901,
#  'exposed': 2740,
#  'also': 915,
#  'find': 2873,
#  'her': 3428,
#  'else': 2582,
#  'vomiting': 7362,
#  'there': 6866,
#  'dog': 2398,
#  'cat': 1679,
#  'house': 3526,
#  'let': 4094,
#  'know': 3976,
#  'super': 6640,
#  'replacement': 5742,
#  'murali': 4666,
#  'okay': 4930,
#  've': 7301,
#  'should': 6151,
#  'pick': 5219,
#  'friday': 3019,
#  'hello': 3414,
#  'damn': 2156,
#  'christmas': 1805,
#  'thing': 6876,
#  'think': 6878,
#  'decided': 2210,
#  'keep': 3923,
#  'mp3': 4626,
#  'doesnt': 2397,
#  'ard': 1035,
#  'sac': 5903,
#  'score': 5979,
#  'big': 1343,
#  'hundred': 3560,
#  'set': 6065,
#  'batsman': 1238,
#  'purity': 5526,
#  'friendship': 3026,
#  'two': 7127,
#  'smiling': 6287,
#  'reading': 5624,
#  'forwarded': 2983,
#  'seeing': 6018,
#  'name': 4700,
#  'gud': 3280,
#  'evng': 2697,
#  'musthu': 4676,
#  'sorry': 6357,
#  '500': 537,
#  'mobiles': 4558,
#  '2004': 346,
#  'must': 4675,
#  'nokia': 4819,
#  '89545': 702,
#  'collect': 1886,
#  'yours': 7753,
#  'only': 4959,
#  'tc': 6757,
#  'biz': 1368,
#  '2optout': 409,
#  '087187262701': 140,
#  '50gbp': 540,
#  'mtmsg18': 4645,
#  'aiyo': 878,
#  'poor': 5324,
#  'wan': 7411,
#  'eat': 2530,
#  'bathe': 1236,
#  'tell': 6784,
#  'bad': 1193,
#  'character': 1725,
#  'which': 7529,
#  'dnt': 2381,
#  'lik': 4119,
#  'try': 7090,
#  'change': 1718,
#  'add': 799,
#  'tat': 6743,
#  'year': 7719,
#  'resolution': 5767,
#  'waiting': 7397,
#  'frank': 2994,
#  'morning': 4603,
#  'imagine': 3631,
#  'finally': 2870,
#  'sink': 6209,
#  'into': 3727,
#  'bath': 1235,
#  'through': 6908,
#  'paces': 5062,
#  'maybe': 4410,
#  'even': 2676,
#  'while': 7530,
#  'cage': 1594,
#  'cock': 1869,
#  'surrounded': 6664,
#  'water': 7442,
#  'reminding': 5722,
#  'who': 7535,
#  'owns': 5057,
#  'enjoy': 2617,
#  'cuck': 2110,
#  'knew': 3972,
#  'giving': 3161,
#  'break': 1487,
#  'few': 2837,
#  'times': 6935,
#  'woul': 7650,
#  'lead': 4063,
#  'wanting': 7419,
#  'miss': 4521,
#  'curfew': 2121,
#  'gibe': 3144,
#  'til': 6931,
#  'one': 4953,
#  'midnight': 4482,
#  'movie': 4622,
#  'getsleep': 3135,
#  'anything': 984,
#  'studdying': 6563,
#  'ear': 2515,
#  'training': 7047,
#  'private': 5440,
#  '2003': 345,
#  'account': 774,
#  'statement': 6485,
#  'shows': 6164,
#  '800': 631,
#  'un': 7165,
#  'redeemed': 5674,
#  'points': 5304,
#  '08718738001': 148,
#  'identifier': 3605,
#  'code': 1872,
#  '49557': 509,
#  'expires': 2735,
#  '26': 370,
#  '11': 267,
#  '04': 16,
#  'guess': 3284,
#  'useless': 7259,
#  'calling': 1616,
#  'important': 3644,
#  'entry': 2634,
#  'weekly': 7482,
#  'comp': 1916,
#  'chance': 1716,
#  'win': 7562,
#  'ipod': 3748,
#  'pod': 5300,
#  '80182': 639,
#  'std': 6494,
#  'rate': 5599,
#  '08452810073': 70,
#  'details': 2283,
#  '18': 319,
#  'wnt': 7607,
#  'buy': 1577,
#  'bmw': 1406,
#  'car': 1646,
#  'urgently': 7244,
#  'vry': 7369,
#  'urgent': 7243,
#  'hv': 3578,
#  'shortage': 6143,
#  'lacs': 4006,
#  'source': 6370,
#  'arng': 1055,
#  'dis': 2348,
#  'amt': 941,
#  'thats': 6846,
#  'prob': 5447,
#  'winner': 7570,
#  'specially': 6395,
#  'selected': 6028,
#  'receive': 5651,
#  'holiday': 3480,
#  'flights': 2913,
#  'inc': 3655,
#  'speak': 6389,
#  'live': 4164,
#  'operator': 4977,
#  '0871277810810': 114,
#  'adult': 819,
#  'content': 1980,
#  'shortly': 6147,
#  'forgot': 2970,
#  'babe': 1182,
#  'love': 4240,
#  'ya': 7705,
#  'missing': 4525,
#  'pray': 5383,
#  'inshah': 3703,
#  'allah': 902,
#  'information': 3690,
#  'o2': 4886,
#  'user': 7260,
#  'lucky': 4269,
#  'why': 7543,
#  'log': 4189,
#  'onto': 4962,
#  'urawinner': 7240,
#  'com': 1896,
#  'fantastic': 2793,
#  'surprise': 6662,
#  'awaiting': 1160,
#  'mmm': 4545,
#  'fuck': 3046,
#  'merry': 4463,
#  'how': 3531,
#  'dare': 2165,
#  'ring': 5818,
#  'hi': 3439,
#  'hope': 3501,
#  'better': 1326,
#  'night': 4792,
#  'sky': 6240,
#  'quite': 5558,
#  'dark': 2166,
#  'liao': 4100,
#  'raining': 5577,
#  'excuse': 2715,
#  'run': 5889,
#  'rite': 5829,
#  'hee': 3406,
#  'any': 978,
#  'special': 6391,
#  'great': 3250,
#  'bye': 1589,
#  'email': 2586,
#  'sooooo': 6352,
#  'much': 4650,
#  'wish': 7578,
#  'sleep': 6249,
#  'bed': 1278,
#  'lonely': 4202,
#  'dream': 2454,
#  'mr': 4628,
#  'foley': 2937,
#  'more': 4599,
#  'exciting': 2714,
#  'prizes': 5444,
#  'eye': 2751,
#  'visit': 7346,
#  '82050': 649,
#  'boo': 1421,
#  'moms': 4579,
#  'making': 4342,
#  'tortilla': 7024,
#  'soup': 6369,
#  'yummmm': 7763,
#  'yay': 7716,
#  'party': 5113,
#  'together': 6978,
#  'delhi': 2239,
#  'still': 6513,
#  'silent': 6192,
#  'yep': 7728,
#  'pink': 5238,
#  'furniture': 3066,
#  'tho': 6893,
#  'bloo': 1393,
#  'bowl': 1449,
#  'corporation': 2011,
#  'gap': 3088,
#  'mind': 4496,
#  'probably': 5448,
#  'tomorrow': 6996,
#  'chosen': 1801,
#  '350': 447,
#  'award': 1162,
#  'number': 4870,
#  '09066364311': 229,
#  'valued': 7287,
#  'cool': 2001,
#  'swimming': 6687,
#  'pool': 5322,
#  'jacuzzi': 3793,
#  'juz': 3895,
#  'both': 1442,
#  'us': 7252,
#  'available': 1146,
#  'soiree': 6318,
#  'june': 3886,
#  '3rd': 470,
#  'has': 3360,
#  'ride': 5812,
#  'crashing': 2062,
#  'place': 5246,
#  'dave': 2184,
#  'final': 2868,
#  'tenerife': 6797,
#  '09061743806': 196,
#  'landline': 4017,
#  'tcs': 6759,
#  'sae': 5908,
#  'box326': 1455,
#  'cw25wx': 2141,
#  '150ppm': 309,
#  'wen': 7495,
#  'spiritual': 6417,
#  'deep': 2218,
#  'theory': 6863,
#  'argument': 1046,
#  'wins': 7572,
#  'situation': 6224,
#  'loses': 4222,
#  'person': 5182,
#  'argue': 1044,
#  'friends': 3024,
#  'kick': 3942,
#  'amp': 937,
#  'say': 5958,
#  'correct': 2013,
#  'depends': 2260,
#  'quality': 5545,
#  'type': 7141,
#  'sent': 6049,
#  'boye': 1468,
#  'faded': 2763,
#  'glory': 3168,
#  'ralphs': 5587,
#  'happened': 3342,
#  'never': 4770,
#  'came': 1623,
#  'sends': 6044,
#  'greetings': 3258,
#  'girl': 3152,
#  'does': 2394,
#  'stay': 6489,
#  'doesn': 2396,
#  'recovery': 5669,
#  'time': 6934,
#  'id': 3600,
#  'rather': 5601,
#  'pass': 5116,
#  'fun': 3056,
#  'cooped': 2002,
#  'minor': 4507,
#  'shindig': 6118,
#  'interested': 3719,
#  'dreams': 2455,
#  'true': 7083,
#  'bit': 1362,
#  'weird': 7486,
#  'supposed': 6652,
#  'happening': 3344,
#  'idea': 3602,
#  'sure': 6656,
#  'they': 6872,
#  'gift': 3145,
#  'didnt': 2313,
#  'jade': 3795,
#  'paul': 5132,
#  'didn': 2312,
#  'barmed': 1222,
#  'talk': 6724,
#  'ffffffffff': 2840,
#  'alright': 913,
#  'sooner': 6348,
#  'alter': 916,
#  'answerin': 970,
#  'phone': 5206,
#  'actually': 796,
#  'pretty': 5419,
#  'reasonable': 5639,
#  'sleepy': 6254,
#  'don': 2413,
#  'raping': 5598,
#  'dudes': 2492,
#  'poker': 5305,
#  'library': 4103,
#  'reverse': 5798,
#  'cheating': 1745,
#  'mathematics': 4394,
#  'joking': 3859,
#  'oni': 4955,
#  'yourself': 7754,
#  'safe': 5909,
#  'envy': 2640,
#  'real': 5626,
#  'life': 4109,
#  'gave': 3102,
#  'photo': 5212,
#  'registered': 5695,
#  'ah': 859,
#  'wanna': 7414,
#  'yck': 7717,
#  'mob': 4556,
#  'tones': 6999,
#  'ready': 5625,
#  'download': 2438,
#  'include': 3660,
#  'crazy': 2065,
#  'frog': 3037,
#  'axel': 1169,
#  'akon': 882,
#  'black': 1370,
#  'eyed': 2752,
#  'info': 3688,
#  'applausestore': 1007,
#  'monthlysubscription': 4594,
#  '50p': 541,
#  'msg': 4633,
#  'max6': 4406,
#  'csc': 2098,
#  'web': 7465,
#  'age16': 851,
#  '2stop': 414,
#  'plural': 5276,
#  'noun': 4854,
#  'research': 5758,
#  'sentence': 6050,
#  'concentrate': 1941,
#  'educational': 2546,
#  'career': 1652,
#  'yeah': 7718,
#  'mmmmmmm': 4549,
#  'snuggles': 6310,
#  'contented': 1981,
#  'sigh': 6183,
#  'whispers': 7532,
#  'fucking': 3049,
#  'barely': 1221,
#  'stand': 6466,
#  'cup': 2118,
#  'coffee': 1873,
#  'animation': 955,
#  'wishing': 7582,
#  'family': 2785,
#  'mas': 4382,
#  'advance': 821,
#  'watching': 7440,
#  'footie': 2954,
#  'worried': 7639,
#  'blow': 1397,
#  'phil': 5201,
#  'neville': 4772,
#  'take': 6717,
#  'care': 1650,
#  'aight': 868,
#  'mum': 4658,
#  'leh': 4082,
#  'reach': 5616,
#  'budget': 1543,
#  'money': 4583,
#  'gary': 3095,
#  'freak': 2999,
#  'lmao': 4175,
#  'wont': 7622,
#  'needing': 4745,
#  'hair': 3313,
#  'anymore': 980,
#  'moby': 4566,
#  'quiz': 5560,
#  '100': 256,
#  'high': 3443,
#  'street': 6544,
#  'duchess': 2489,
#  'cornwall': 2010,
#  '82277': 652,
#  'unsub': 7214,
#  '50': 536,
#  '008704050406': 3,
#  'sp': 6377,
#  'arrow': 1067,
#  'train': 7045,
#  'worc': 7627,
#  'foregate': 2960,
#  'shrub': 6168,
#  'hill': 3445,
#  'said': 5914,
#  'shit': 6126,
#  'plz': 5279,
#  'asks': 1089,
#  'disconnect': 2356,
#  'coz': 2048,
#  'iz': 3784,
#  'attempt': 1118,
#  'terrorist': 6809,
#  'use': 7256,
#  'sim': 6195,
#  'card': 1647,
#  'itz': 3780,
#  'confirmd': 1956,
#  'motorola': 4614,
#  'verified': 7309,
#  'cnn': 1861,
#  'ibn': 3591,
#  'facebook': 2759,
#  'ten': 6794,
#  'years': 7720,
#  'shower': 6159,
#  'ringtone': 5821,
#  'changed': 1719,
#  '25': 365,
#  'credits': 2074,
#  'club4mobiles': 1853,
#  'choose': 1798,
#  'club': 1851,
#  '87070': 681,
#  '150p': 305,
#  'wk': 7595,
#  'club4': 1852,
#  'po': 5282,
#  'box1146': 1452,
#  'mk45': 4542,
#  '2wt': 422,
#  'gain': 3076,
#  'rights': 5816,
#  'wife': 7550,
#  'demand': 2248,
#  'trying': 7092,
#  'husband': 3574,
#  'lets': 4095,
#  'added': 801,
#  'their': 6854,
#  'contact': 1976,
#  'list': 4152,
#  'fullonsms': 3055,
#  'sms': 6292,
#  'people': 5163,
#  'howz': 3538,
#  'pain': 5072,
#  'being': 1302,
#  'contacted': 1977,
#  'dating': 2182,
#  'someone': 6325,
#  'land': 4016,
#  'line': 4134,
#  '09050000928': 162,
#  'pobox45w2tg150p': 5292,
#  'getting': 3138,
#  'wonderful': 7619,
#  'caring': 1658,
#  'best': 1320,
#  'god': 3180,
#  'ystrday': 7761,
#  'ice': 3595,
#  'medicine': 4430,
#  'fb': 2814,
#  'jaykwon': 3813,
#  'thuglyfe': 6916,
#  'falconerf': 2777,
#  'point': 5303,
#  'figure': 2855,
#  'wn': 7605,
#  'hurt': 3571,
#  'prsn': 5499,
#  'close': 1842,
#  'fight': 2851,
#  'wit': 7585,
#  'dem': 2247,
#  'somtimes': 6340,
#  'saves': 5955,
#  'relation': 5701,
#  'bt': 1535,
#  'quiet': 5556,
#  'leaves': 4073,
#  'nothin': 4848,
#  'eveb': 2675,
#  'again': 848,
#  'address': 804,
#  'press': 5412,
#  'conference': 1952,
#  'talking': 6728,
#  'issue': 3767,
#  'weigh': 7484,
#  'thanks': 6836,
#  'breathe': 1493,
#  'easier': 2523,
#  'regret': 5697,
#  'door': 2423,
#  'ma': 4298,
#  'fan': 2787,
#  'dunno': 2500,
#  'lido': 4106,
#  'same': 5927,
#  '930': 717,
#  'lol': 4197,
#  'grr': 3271,
#  'mom': 4576,
#  'taking': 6722,
#  'forever': 2962,
#  'prescription': 5405,
#  'pharmacy': 5198,
#  'minutes': 4512,
#  'away': 1164,
#  'ugh': 7149,
#  'another': 965,
#  'min': 4493,
#  'polo': 5311,
#  'ltd': 4263,
#  'suite': 6617,
#  '373': 453,
#  'london': 4200,
#  'w1j': 7377,
#  '6hl': 596,
#  'fuckin': 3048,
#  'under': 7178,
#  'sea': 6000,
#  'lays': 4055,
#  'rock': 5838,
#  'envelope': 2638,
#  'paper': 5087,
#  'words': 7629,
#  'wah': 7388,
#  'man': 4347,
#  'soo': 6346,
#  '2morrow': 402,
#  'xxx': 7697,
#  'parents': 5098,
#  'kidz': 3949,
#  'colleagues': 1885,
#  'screaming': 5990,
#  'sofa': 6315,
#  'naked': 4698,
#  'believe': 1303,
#  'thk': 6887,
#  'missed': 4523,
#  'alert': 890,
#  'these': 6868,
#  'numbers': 4871,
#  'called': 1610,
#  '07008009200': 23,
#  'cut': 2134,
#  'short': 6142,
#  'failed': 2767,
#  'sad': 5907,
#  'plm': 5273,
#  'office': 4914,
#  'aint': 870,
#  'cozy': 2049,
#  'exhausted': 2721,
#  'last': 4033,
#  'nobody': 4813,
#  'everything': 2692,
#  'closed': 1844,
#  'madam': 4314,
#  'disturbance': 2370,
#  'might': 4484,
#  'reference': 5678,
#  'dlf': 2379,
#  'premarica': 5396,
#  'kindly': 3957,
#  'informed': 3691,
#  'rgds': 5804,
#  'rakhesh': 5584,
#  'kerala': 3930,
#  'anyways': 988,
#  'gym': 3299,
#  'whatever': 7514,
#  'smiles': 6285,
#  'hot': 3519,
#  'air': 871,
#  'balloon': 1205,
#  'jay': 3811,
#  'er': 2644,
#  '15': 302,
#  'cafe': 1593,
#  'sit': 6218,
#  'de': 2193,
#  'yijue': 7737,
#  'gek1510': 3118,
#  'hide': 3441,
#  'anythiing': 982,
#  'keeping': 3924,
#  'distance': 2367,
#  '2nd': 406,
#  '900': 712,
#  'yesterday': 7732,
#  'collection': 1889,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(7780,))

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 841,  943, 1902, 3318, 3485, 3523, 4929, 6861, 6968, 7239, 7559]),)

# %%
X_train[:4]
# Out:
# 4103    Ok then i will come to ur home after half an hour
# 2965    Do you ever notice that when you're driving, a...
# 877          Are you in castor? You need to see something
# 4209    Or i go home first lar ü wait 4 me lor.. I put...
# Name: Message, dtype: str

# %%
X_train_np[0][1771]
# Out:
# np.int64(0)

# %% [markdown]
# <h3>Train the naive bayes model</h3>

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %% [markdown]
# <h3>Evaluate Performance</h3>

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       976
#            1       0.99      0.94      0.96       139
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.97      0.98      1115
# weighted avg       0.99      0.99      0.99      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1])

# %% [markdown]
# <h3>Train the model using sklearn pipeline and reduce number of lines of code</h3>

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       976
#            1       0.99      0.94      0.96       139
#
#     accuracy                           0.99      1115
#    macro avg       0.99      0.97      0.98      1115
# weighted avg       0.99      0.99      0.99      1115
